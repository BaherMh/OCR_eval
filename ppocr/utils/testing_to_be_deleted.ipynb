# %%
import chardet

with open(r"../../../Train_data/Train.csv", "rb") as f:
    rawdata = f.read()
    result = chardet.detect(rawdata)
    print(result)
# Out:
# {'encoding': 'utf-8', 'confidence': 0.99, 'language': ''}

# %%
import csv

csv_path = r"C:/Users/baher/OneDrive/Desktop/masters/masters thesis/paddleOCR/Train_data/Test.csv"

data = [
    ["C:/Users/baher/OneDrive/Desktop/masters/masters thesis/paddleOCR/Train_data/Test/2.png", "влюбленный"],
    ["C:/Users/baher/OneDrive/Desktop/masters/masters thesis/paddleOCR/Train_data/Test/3.png", "норвежец"]
]

with open(csv_path, "w", newline="", encoding="utf-8") as f:
    writer = csv.writer(f)  # default delimiter=","
    writer.writerows(data)

print(f"CSV saved at {csv_path}")
# Out:
# CSV saved at C:/Users/baher/OneDrive/Desktop/masters/masters thesis/paddleOCR/Train_data/Test.csv
